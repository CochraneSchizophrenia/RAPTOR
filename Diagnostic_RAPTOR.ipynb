# %% [markdown]
# <a href="https://colab.research.google.com/github/CochraneSchizophrenia/RAPTOR/blob/master/Diagnostic_RAPTOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### DR-RAPTOR (Diagnostic Review - RevmAn Parsing TOol for Reviewers)
#
# DR-RAPTOR is a newer, lighter version of the RAPTOR tool which was originally published here:
#
# > *Schmidt, L., Shokraneh, F., Steinhausen, K., Adams, CE. Introducing RAPTOR: RevMan Parsing Tool for Reviewers. Syst Rev 8, 151 (2019). https://doi.org/10.1186/s13643-019-1070-0*
#
#
# In comparison to the old tool, DR-RAPTOR focuses on diagnostic data (not interventional!), its coded in Python and available via this online notebook. The old tool is a true dinosaur, running on Java 1.7 on desktop....
#
# ### Directions of use for DR-RAPTOR:
#
# Please create your own runnable copy of this Python Notebook in order to run the tool.
#
# Run the tool by clicking the button in the top left corner of the cell below this text field (appears on hover, next to the 'SHOW CODE' text).
#
# Click on 'Choose Files' button that will appear within or on the bottom of the next cell.
#
# Batch-select your .rm5 files (tool will only parse them if the file extension is **.rm5)**.
#
# Loading and parsing the data might take a few minutes, but during the process some information will appear. First, data will be uploaded, and this is the part where you might wait. The actual data extraction and parsing is super quick!
#
# This tool is optimised for **diagnostic accuracy systematic reviews and their associated data.** If you try and parse interventional reviews they you might not get a complete export, and statistical data will be missing.
#
# Upon completion the browser should offer 3 csv files for download, or it will download them directly, depending on browser settings. One file with basic review metadata and stats (title, doi, year of publication, year of last search, age of included studies ...). Alternatively, those .csv files should become available in the sidebar on the left, between or below the uploaded review files.
#
# The two other files will contain risk of bias data and numeric data from the included studies.
#
# **Caveat:** especially in terms of content there are two types of .rm5 files ->
#
# 1. Complete data files supplied by Cochrane or single Cochrane groups which includes review text and full characteristics.
#
# 2. The stats-only download .rm5 files that are accessible on the Cochrane Library next to review publications (note, in June 2021 there is a pop-up for a user to confirm they will only use RevMan to read these files). Stats only files are potentially preferable for quality because review-group-supplied files might have been changed after last publication and therefore could represent non-peer-reviewed content.
#
# The original RAPTOR, or DR-RAPTOR are not coded or designed to systematically extract results of meta-analyses or copyrighted text! The purpose is to extract study-based data for re-analysis or re-use in research contexts.

# %%
#@title

import xml.etree.ElementTree as xml
from xml.etree.ElementTree import Element
from typing import TypeVar
from typing import Optional
from statistics import median, mean
import pandas as pd
from google.colab import files
import copy

import os

def getAttribute(element: TypeVar("Element"), path: str, default: str = None)-> str:
    result= element.get(path)
    if result==None or len(result) ==0:
      return default
    else:
      return result

def getChildTexts(element: TypeVar("Element"), path: str, default: str = None, separator: str = "\n") -> str:
  # Find the path in the element
    result = element.findall(path)

    # Return the default if there is no such element
    if result is None or len(result) == 0:
        return default

    # Extract the text and return it
    else:
      all_text=[]
      for item in result:
        all_text.extend(item.itertext())
      my_t=" ".join(all_text).replace("\n", "")
      #print(my_t)
      return my_t


# def getContent(#this method is not so good because it fails to extract nested text within tags such as <SUP>
#     element: TypeVar("Element"), path: str, default: str = None, separator: str = "\n"
# ) -> str:
#     """ Internal helper method that retrieves the text content of an
#         XML element.

#         Parameters:
#             - element   Element, the XML element to parse.
#             - path      Str, Nested path in the XML element.
#             - default   Str, default value to return when no text is found.

#         Returns:
#             - text      Str, text in the XML node.
#     """

#     # Find the path in the element
#     result = element.findall(path)

#     # Return the default if there is no such element
#     if result is None or len(result) == 0:
#         return default

#     # Extract the text and return it
#     else:
#         # print("more than 1")
#         # print(separator.join([sub.text for sub in result if sub.text is not None]))
#         return separator.join([sub.text for sub in result if sub.text is not None])


def get_basic_data(root, default="Data not found"):
  #############################
  #Function to retrieve 'basic' metadata from a rm5, such as DOI, title, but also data of publication, date of last search, and year of studies published
  #
  #Guide to extension: Any new data item can be added to the dictionary 'review_data'. By defining an xml path from the XML root element, data can be extracted from any place of the .rm5 
  #
  #############################
  review_data={}

  review_data["IS_QUADAS_2"]=getAttribute(root, "QUADAS2", default=default)
  review_data["REVIEW_TYPE"]=getAttribute(root, "TYPE", default=default)
  review_data["REVIEW_DOI"]=getAttribute(root, "DOI", default=default)
  review_data["REVIEW_GROUP"]=getAttribute(root, "GROUP_ID", default=default)
  
  year= getAttribute(root.find(".//COVER_SHEET//DATES//LAST_SEARCH//DATE"), "YEAR", default=default)
  month= getAttribute(root.find(".//COVER_SHEET//DATES//LAST_SEARCH//DATE"), "MONTH", default=default)
  review_data["LAST_SEARCH"]= "{}/{} last searched".format(month,year)

  review_data["REVIEW_PUBLISHED_YEAR"]= getAttribute(root.find(".//COVER_SHEET//DATES//LAST_CITATION_ISSUE"), "YEAR", default=default)


  review_data["REVIEW_TITLE"]=getChildTexts(root.find(".//COVER_SHEET"), "TITLE", default=default)
  

  included_studies=root.findall(".//STUDIES_AND_REFERENCES//STUDIES//INCLUDED_STUDIES//STUDY")
  review_data["NUM_INCLUDED_STUDIES"]=len(included_studies)
  years=[]
  ids=[]


  for elem in included_studies:
    ids.append(getAttribute(elem, "ID", default=default))
    years.append(getAttribute(elem, "YEAR", default=default))

  int_years=[]
  for y in years:
    if y != default:
      try:
        int_years.append(int(y))
      except:
        pass

  
  review_data["MEAN_INCL_STUDIES_PUBLISHED"]=int(mean(int_years))
  review_data["MEDIAN_INCL_STUDIES_PUBLISHED"]=int(median(int_years))
  review_data["INCL_STUDY_YEARS"]="; ".join(years)
  review_data["INCL_STUDY_IDs"]="; ".join(ids)



  #print(review_data)
  return review_data, ids
def get_bias_data(root, review_data, default="Data not found"):
  
  bias_items=root.findall(".//QUALITY_ITEMS//QUALITY_ITEM")
  all_data=[]

  for elem in bias_items:
    basic={}#add some data for each bias domain
    basic["BIAS_ELEMENT_ID"]=getAttribute(elem, "ID", default=default)
    
    basic["BIAS_LEVEL_OF_ASSESSMENT"]=getAttribute(elem, "LEVEL", default=default)
    basic["CHARACTERISTIC"]=getAttribute(elem, "CHARACTERISTIC", default=default)
    basic["IS_CORE_ITEM"]=getAttribute(elem, "CORE_ITEM", default=default)
    basic["DOMAIN_NR"]=getAttribute(elem, "DOMAIN", default=default)
    basic["DOMAIN_NAME"]=getAttribute(elem, "DOMAIN_NAME", default=default)
    basic["SIGNALLING_QUESTION"]=getChildTexts(elem, "NAME", default=default)
    basic["SIGNALLING_QUESTION_DESCRIPTION"]=getChildTexts(elem,"DESCRIPTION", separator=" ", default=default)


    bias_data=elem.findall(".//QUALITY_ITEM_DATA")
    for d in bias_data:
      bias_entries=d.findall(".//QUALITY_ITEM_DATA_ENTRY")
      for entry in bias_entries:
        this_result=copy.deepcopy(basic)#add some data for each bias item
        this_result["RESULT"]=getAttribute(entry, "RESULT", default=default)
        this_result["JUDGEMENT_TEXT"]=getChildTexts(entry,"DESCRIPTION", separator=" ", default=default)
        
        this_result["STUDY_ID"]=getAttribute(entry, "STUDY_ID", default=default)

        this_result["REVIEW_TITLE"]=review_data["REVIEW_TITLE"]#add some review metadata
        this_result["REVIEW_PUBLISHED_YEAR"]=review_data["REVIEW_PUBLISHED_YEAR"]
        this_result["REVIEW_DOI"]=review_data["REVIEW_DOI"]
        this_result["IS_QUADAS_2"]=review_data["IS_QUADAS_2"]
    


        all_data.append(this_result)
  #print(all_data)
  return all_data

def get_stats_data(root, review_data, default="Data not found"):
  
  stats_items=root.findall(".//ANALYSES_AND_DATA//TESTS//TEST")
  all_data=[]

  for elem in stats_items:
    basic={}#add some data for each bias domain
    basic["STATS_ELEMENT_ID"]=getAttribute(elem, "ID", default=default)
    
    
    basic["SUB_NAME"]=getChildTexts(elem, "NAME", default=default)
    basic["FULL_NAME"]=getChildTexts(elem, "FULL_NAME", default=default)
    basic["DESCRIPTION"]=getChildTexts(elem,"DESCRIPTION", separator=" ", default=default)


    test_data=elem.findall(".//TEST_DATA")
    for d in test_data:
      test_entries=d.findall(".//TEST_DATA_ENTRY")
      for entry in test_entries:
        this_result=copy.deepcopy(basic)#add some data for each bias item
        
        this_result["FN"]=getAttribute(entry, "FN", default=default)
        this_result["FP"]=getAttribute(entry, "FP", default=default)
        this_result["TN"]=getAttribute(entry, "TN", default=default)
        this_result["TP"]=getAttribute(entry, "TP", default=default)
        
        
        this_result["STUDY_ID"]=getAttribute(entry, "STUDY_ID", default=default)

        this_result["REVIEW_TITLE"]=review_data["REVIEW_TITLE"]#add some review metadata
        this_result["REVIEW_PUBLISHED_YEAR"]=review_data["REVIEW_PUBLISHED_YEAR"]
        this_result["REVIEW_DOI"]=review_data["REVIEW_DOI"]
    


        all_data.append(this_result)
  #print(all_data)
  return all_data

def get_elements(xml_path:str, path_bias:str="", path_data:str=""):
  #RETURNS a dict for basic review data, and list of dict for all bias and result items (one dict per study per item)
  root = xml.parse(xml_path).getroot()
  review_data, ids = get_basic_data(root)
  bias_items = get_bias_data(root, review_data)
  stats_items=get_stats_data(root, review_data)

  
  #print(getAttribute(root.find(".//COVER_SHEET"), "MODIFIED_BY"))
  return review_data, bias_items, stats_items

##############################################################################################
# data_path="/content/drive/MyDrive/Diagnostic_files"#use this two lines instead of the next two if data are already in gdrive - will speed up significantly!!!!!!
# rm5_files=[os.path.join(data_path,f) for f in os.listdir(data_path) if ".rm5" in f]#grab all files
uploaded = files.upload()
rm5_files=[f for f in uploaded.keys() if ".rm5" in f]#grab all files
################################################################################################

basic_data=[]
basic_data_colnames=set()

bias_data=[]
bias_data_colnames=set()

stats_data=[]
stats_data_colnames=set()


#rm5_files=[f for f in files if ".rm5" in f]#use only .rm5 files
counter=0
for f in rm5_files:
  print("\nExtracting data from: {} ...".format(f))
  print("   Extracting basic review info, bias data, stats data...")
  review_data, bias_items, stats_items=get_elements(f)

  basic_data.append(review_data)#append this single dict
  basic_data_colnames.update(list(review_data.keys()))#amake sure every entry has a column name

  bias_data.extend(bias_items)

  for i in bias_items:
    bias_data_colnames.update(list(i.keys()))
  
  stats_data.extend(stats_items)

  for i in stats_items:
    stats_data_colnames.update(list(i.keys()))

  print("   Extracted: review metadata n={}; Study bias data n={} items; Study result data n={} results".format(1,len(bias_items), len(stats_data)))
  
  counter+=1

basic_df=pd.DataFrame(basic_data, columns=list(basic_data_colnames))
basic_df.to_csv("basic_review_data.csv", index=False, encoding ='utf-8')

bias_df=pd.DataFrame(bias_data, columns=list(bias_data_colnames))
bias_df.to_csv("bias_review_data.csv", index=False,encoding ='utf-8')

stats_df=pd.DataFrame(stats_data, columns=list(stats_data_colnames))
stats_df.to_csv("stats_review_data.csv", index=False,encoding ='utf-8')

files.download("basic_review_data.csv")
files.download("bias_review_data.csv")
files.download("stats_review_data.csv")

print("------Extracted data from {} reviews----".format(counter))
# Out:
#      <input type="file" id="files-86cddd0f-5369-4a0a-bd40-852f0d839ed9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86cddd0f-5369-4a0a-bd40-852f0d839ed9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CD007394 v. 4.0 Galactomannan detection for invasive aspergillosis in immunocompromised patients.rm5 to CD007394 v. 4.0 Galactomannan detection for invasive aspergillosis in immunocompromised patients.rm5
# Saving CD007427 v. 3.0 Physical tests for shoulder impingements and local lesions of bursa tendon or labrum that may accom.rm5 to CD007427 v. 3.0 Physical tests for shoulder impingements and local lesions of bursa tendon or labrum that may accom.rm5
# Saving CD007431 v. 4.0 Physical examination for lumbar radiculopathy due to disc herniation in patients with low-back pain.rm5 to CD007431 v. 4.0 Physical examination for lumbar radiculopathy due to disc herniation in patients with low-back pain.rm5
# Saving CD008054 v. 7.0 Human papillomavirus testing versus repeat cytology for triage of minor cytological cervical lesions.rm5 to CD008054 v. 7.0 Human papillomavirus testing versus repeat cytology for triage of minor cytological cervical lesions.rm5
# Saving CD008081 v. 4.0 Optical coherence tomography (OCT) for detection of macular oedema in patients with diabetic retinop.rm5 to CD008081 v. 4.0 Optical coherence tomography (OCT) for detection of macular oedema in patients with diabetic retinop.rm5
# Saving CD008122 v. 4.0 Rapid diagnostic tests for diagnosing uncomplicated P. falciparum malaria in endemic countries.rm5 to CD008122 v. 4.0 Rapid diagnostic tests for diagnosing uncomplicated P. falciparum malaria in endemic countries.rm5
# Saving CD008587 v. 3.0 Cytology versus HPV testing for cervical cancer screening in the general population.rm5 to CD008587 v. 3.0 Cytology versus HPV testing for cervical cancer screening in the general population.rm5
# Saving CD008643 v. 4.3 Red flags to screen for vertebral fracture in patients presenting with low-back pain.rm5 to CD008643 v. 4.3 Red flags to screen for vertebral fracture in patients presenting with low-back pain.rm5
# Saving CD008686 v. 3.2 Red flags to screen for malignancy in patients with low-back pain.rm5 to CD008686 v. 3.2 Red flags to screen for malignancy in patients with low-back pain.rm5
# Saving CD008691 v. 2.0 Cardiac testing for coronary artery disease in potential kidney transplant recipients.rm5 to CD008691 v. 2.0 Cardiac testing for coronary artery disease in potential kidney transplant recipients.rm5
# Saving CD008759 v. 3.0 Platelet count spleen length and platelet count-to-spleen length ratio for the diagnosis of oesoph.rm5 to CD008759 v. 3.0 Platelet count spleen length and platelet count-to-spleen length ratio for the diagnosis of oesoph.rm5
# Saving CD008760 v. 3.0 Capsule endoscopy for the diagnosis of oesophageal varices in people with chronic liver disease or p.rm5 to CD008760 v. 3.0 Capsule endoscopy for the diagnosis of oesophageal varices in people with chronic liver disease or p.rm5
# Saving CD008782 v. 4.0 Plasma and cerebrospinal fluid amyloid beta for the diagnosis of Alzheimer's disease dementia and ot.rm5 to CD008782 v. 4.0 Plasma and cerebrospinal fluid amyloid beta for the diagnosis of Alzheimer's disease dementia and ot.rm5
# Saving CD008803 v. 2.0 Optic nerve head and fibre layer imaging for diagnosing glaucoma.rm5 to CD008803 v. 2.0 Optic nerve head and fibre layer imaging for diagnosing glaucoma.rm5
# Saving CD008874 v. 6.0 Airway physical examination tests for detection of difficult airway management in apparently normal .rm5 to CD008874 v. 6.0 Airway physical examination tests for detection of difficult airway management in apparently normal .rm5
# Saving CD008892 v. 2.0 Rapid diagnostic tests for typhoid and paratyphoid (enteric) fever.rm5 to CD008892 v. 2.0 Rapid diagnostic tests for typhoid and paratyphoid (enteric) fever.rm5
# Saving CD009020 v. 3.0 Magnetic resonance imaging magnetic resonance arthrography and ultrasonography for assessing rotato.rm5 to CD009020 v. 3.0 Magnetic resonance imaging magnetic resonance arthrography and ultrasonography for assessing rotato.rm5
# Saving CD009044 v. 2.0 Diagnostic tests for autism spectrum disorder (ASD) in preschool children.rm5 to CD009044 v. 2.0 Diagnostic tests for autism spectrum disorder (ASD) in preschool children.rm5
# Saving CD009135 v. 2.1 Rapid tests for the diagnosis of visceral leishmaniasis in patients with suspected disease.rm5 to CD009135 v. 2.1 Rapid tests for the diagnosis of visceral leishmaniasis in patients with suspected disease.rm5
# Saving CD009175 v. 2.0 Clinical symptoms and signs for the diagnosis of Mycoplasma pneumoniae in children and adolescents w.rm5 to CD009175 v. 2.0 Clinical symptoms and signs for the diagnosis of Mycoplasma pneumoniae in children and adolescents w.rm5
# Saving CD009185 v. 2.163 Procalcitonin C-reactive protein and erythrocyte sedimentation rate for the diagnosis of acute pye.rm5 to CD009185 v. 2.163 Procalcitonin C-reactive protein and erythrocyte sedimentation rate for the diagnosis of acute pye.rm5
# Saving CD009263 v. 5.0 123I-MIBG scintigraphy and 18F-FDG-PET imaging for diagnosing neuroblastoma.rm5 to CD009263 v. 5.0 123I-MIBG scintigraphy and 18F-FDG-PET imaging for diagnosing neuroblastoma.rm5
# Saving CD009323 v. 4.0 Diagnostic accuracy of laparoscopy following computed tomography (CT) scanning for assessing the res.rm5 to CD009323 v. 4.0 Diagnostic accuracy of laparoscopy following computed tomography (CT) scanning for assessing the res.rm5
# Saving CD009372 v. 2.0 Computed tomography angiography or magnetic resonance angiography for detection of intracranial vasc.rm5 to CD009372 v. 2.0 Computed tomography angiography or magnetic resonance angiography for detection of intracranial vasc.rm5
# Saving CD009519 v. 4.0 PET-CT for assessing mediastinal lymph node involvement in patients with suspected resectable non-sm.rm5 to CD009519 v. 4.0 PET-CT for assessing mediastinal lymph node involvement in patients with suspected resectable non-sm.rm5
# Saving CD009551 v. 5.2 Polymerase chain reaction blood tests for the diagnosis of invasive aspergillosis in immunocompromis.rm5 to CD009551 v. 5.2 Polymerase chain reaction blood tests for the diagnosis of invasive aspergillosis in immunocompromis.rm5
# Saving CD009579 v. 3.0 Circulating antigen tests and urine reagent strips for diagnosis of active schistosomiasis in endemi.rm5 to CD009579 v. 3.0 Circulating antigen tests and urine reagent strips for diagnosis of active schistosomiasis in endemi.rm5
# Saving CD009591 v. 2.0 Imaging modalities for the non-invasive diagnosis of endometriosis.rm5 to CD009591 v. 2.0 Imaging modalities for the non-invasive diagnosis of endometriosis.rm5
# Saving CD009593 v. 8.4 Xpert MTBRIF and Xpert MTBRIF Ultra for pulmonary tuberculosis and rifampicin resistance in adults.rm5 to CD009593 v. 8.4 Xpert MTBRIF and Xpert MTBRIF Ultra for pulmonary tuberculosis and rifampicin resistance in adults.rm5
# Saving CD009628 v. 2.0 Structural magnetic resonance imaging for the early diagnosis of dementia due to Alzheimer's disease.rm5 to CD009628 v. 2.0 Structural magnetic resonance imaging for the early diagnosis of dementia due to Alzheimer's disease.rm5
# Saving CD009647 v. 3.0 Clinical symptoms signs and tests for identification of impending and current water-loss dehydratio.rm5 to CD009647 v. 3.0 Clinical symptoms signs and tests for identification of impending and current water-loss dehydratio.rm5
# Saving CD009694 v. 4.0 Computed tomography (CT) angiography for confirmation of the clinical diagnosis of brain death.rm5 to CD009694 v. 4.0 Computed tomography (CT) angiography for confirmation of the clinical diagnosis of brain death.rm5
# Saving CD009786 v. 9.0 Laparoscopy for diagnosing resectability of disease in women with advanced ovarian cancer.rm5 to CD009786 v. 9.0 Laparoscopy for diagnosing resectability of disease in women with advanced ovarian cancer.rm5
# Saving CD009925 v. 1.0 Second trimester serum tests for Down's Syndrome screening.rm5 to CD009925 v. 1.0 Second trimester serum tests for Down's Syndrome screening.rm5
# Saving CD009944 v. 2.0 Diagnostic accuracy of endoscopic ultrasonography (EUS) for the preoperative locoregional staging of.rm5 to CD009944 v. 2.0 Diagnostic accuracy of endoscopic ultrasonography (EUS) for the preoperative locoregional staging of.rm5
# Saving CD009977 v. 2.0 Computed tomography for diagnosis of acute appendicitis in adults.rm5 to CD009977 v. 2.0 Computed tomography for diagnosis of acute appendicitis in adults.rm5
# Saving CD010023 v. 2.2 Computed tomography versus magnetic resonance imaging versus bone scintigraphy for clinically suspec.rm5 to CD010023 v. 2.2 Computed tomography versus magnetic resonance imaging versus bone scintigraphy for clinically suspec.rm5
# Saving CD010079 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5 to CD010079 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5
# Saving CD010159 v. 2.0 Calcitonin testing for detection of medullary thyroid cancer in people with thyroid nodules.rm5 to CD010159 v. 2.0 Calcitonin testing for detection of medullary thyroid cancer in people with thyroid nodules.rm5
# Saving CD010173 v. 2.4 Clinical assessment to screen for the detection of oral cavity cancer and potentially malignant diso.rm5 to CD010173 v. 2.4 Clinical assessment to screen for the detection of oral cavity cancer and potentially malignant diso.rm5
# Saving CD010213 v. 2.0 Imaging modalities for characterising focal pancreatic lesions.rm5 to CD010213 v. 2.0 Imaging modalities for characterising focal pancreatic lesions.rm5
# Saving CD010276 v. 2.7 Diagnostic tests for oral cancer and potentially malignant disorders in patients presenting with cli.rm5 to CD010276 v. 2.7 Diagnostic tests for oral cancer and potentially malignant disorders in patients presenting with cli.rm5
# Saving CD010296 v. 2.0 Ultrasonography for endoleak detection after endoluminal abdominal aortic aneurysm repair.rm5 to CD010296 v. 2.0 Ultrasonography for endoleak detection after endoluminal abdominal aortic aneurysm repair.rm5
# Saving CD010339 v. 2.3 Endoscopic retrograde cholangiopancreatography versus intraoperative cholangiography for diagnosis o.rm5 to CD010339 v. 2.3 Endoscopic retrograde cholangiopancreatography versus intraoperative cholangiography for diagnosis o.rm5
# Saving CD010360 v. 5.0 Intraoperative frozen section analysis for the diagnosis of early stage ovarian cancer in suspicious.rm5 to CD010360 v. 5.0 Intraoperative frozen section analysis for the diagnosis of early stage ovarian cancer in suspicious.rm5
# Saving CD010386 v. 2.0 11C-PIB-PET for the early diagnosis of Alzheimers disease dementia and other dementias in people wi.rm5 to CD010386 v. 2.0 11C-PIB-PET for the early diagnosis of Alzheimers disease dementia and other dementias in people wi.rm5
# Saving CD010409 v. 5.0 Sentinel node assessment for diagnosis of groin lymph node involvement in vulval cancer.rm5 to CD010409 v. 5.0 Sentinel node assessment for diagnosis of groin lymph node involvement in vulval cancer.rm5
# Saving CD010438 v. 4.0 Thromboelastography (TEG) and rotational thromboelastometry (ROTEM) for traumainduced coagulopathy .rm5 to CD010438 v. 4.0 Thromboelastography (TEG) and rotational thromboelastometry (ROTEM) for traumainduced coagulopathy .rm5
# Saving CD010502 v. 2.0 Rapid antigen detection test for group A streptococcus in children with pharyngitis.rm5 to CD010502 v. 2.0 Rapid antigen detection test for group A streptococcus in children with pharyngitis.rm5
# Saving CD010542 v. 2.0 Transient elastography for diagnosis of stages of hepatic fibrosis and cirrhosis in people with alco.rm5 to CD010542 v. 2.0 Transient elastography for diagnosis of stages of hepatic fibrosis and cirrhosis in people with alco.rm5
# Saving CD010632 v. 3.0 18F-FDG PET for the early diagnosis of Alzheimers disease dementia and other dementias in people wi.rm5 to CD010632 v. 3.0 18F-FDG PET for the early diagnosis of Alzheimers disease dementia and other dementias in people wi.rm5
# Saving CD010633 v. 2.0 Dopamine transporter imaging for the diagnosis of dementia with Lewy bodies.rm5 to CD010633 v. 2.0 Dopamine transporter imaging for the diagnosis of dementia with Lewy bodies.rm5
# Saving CD010653 v. 2.0 First rank symptoms for schizophrenia.rm5 to CD010653 v. 2.0 First rank symptoms for schizophrenia.rm5
# Saving CD010657 v. 2.0 Dimercaptosuccinic acid scan or ultrasound in screening for vesicoureteral reflux among children wit.rm5 to CD010657 v. 2.0 Dimercaptosuccinic acid scan or ultrasound in screening for vesicoureteral reflux among children wit.rm5
# Saving CD010680 v. 2.0 Ankle brachial index for the diagnosis of lower limb peripheral arterial disease.rm5 to CD010680 v. 2.0 Ankle brachial index for the diagnosis of lower limb peripheral arterial disease.rm5
# Saving CD010705 v. 3.6 GenoType MTBDRsl assay for resistance to second-line anti-tuberculosis drugs.rm5 to CD010705 v. 3.6 GenoType MTBDRsl assay for resistance to second-line anti-tuberculosis drugs.rm5
# Saving CD010722 v. 2.0 Transcranial Doppler sonography for detecting stenosis or occlusion of intracranial arteries in peop.rm5 to CD010722 v. 2.0 Transcranial Doppler sonography for detecting stenosis or occlusion of intracranial arteries in peop.rm5
# Saving CD010771 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5 to CD010771 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5
# Saving CD010772 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5 to CD010772 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5
# Saving CD010775 v. 2.0 Montreal Cognitive Assessment for the diagnosis of Alzheimers disease and other dementias.rm5 to CD010775 v. 2.0 Montreal Cognitive Assessment for the diagnosis of Alzheimers disease and other dementias.rm5
# Saving CD010783 v. 2.0 Mini-Mental State Examination (MMSE) for the detection of Alzheimer's disease and other dementias in.rm5 to CD010783 v. 2.0 Mini-Mental State Examination (MMSE) for the detection of Alzheimer's disease and other dementias in.rm5
# Saving CD010803 v. 2.0 CSF tau and the CSF tauABeta ratio for the diagnosis of Alzheimer's disease dementia and other deme.rm5 to CD010803 v. 2.0 CSF tau and the CSF tauABeta ratio for the diagnosis of Alzheimer's disease dementia and other deme.rm5
# Saving CD010860 v. 2.0 Mini-Cog for the diagnosis of Alzheimer's disease dementia and other dementias within a community se.rm5 to CD010860 v. 2.0 Mini-Cog for the diagnosis of Alzheimer's disease dementia and other dementias within a community se.rm5
# Saving CD010864 v. 3.0 D-dimer test for excluding the diagnosis of pulmonary embolism.rm5 to CD010864 v. 3.0 D-dimer test for excluding the diagnosis of pulmonary embolism.rm5
# Saving CD010896 v. 2.0 Regional Cerebral Blood Flow Single Photon Emission Computed Tomography for detection of Frontotempo.rm5 to CD010896 v. 2.0 Regional Cerebral Blood Flow Single Photon Emission Computed Tomography for detection of Frontotempo.rm5
# Saving CD011021 v. 2.0 Voxel-based morphometry for separation of schizophrenia from other types of psychosis in first episo.rm5 to CD011021 v. 2.0 Voxel-based morphometry for separation of schizophrenia from other types of psychosis in first episo.rm5
# Saving CD011053 v. 2.0 Imaging for the exclusion of pulmonary embolism in pregnancy.rm5 to CD011053 v. 2.0 Imaging for the exclusion of pulmonary embolism in pregnancy.rm5
# Saving CD011121 v. 2.0 AD-8 for detection of dementia across a variety of healthcare settings.rm5 to CD011121 v. 2.0 AD-8 for detection of dementia across a variety of healthcare settings.rm5
# Saving CD011126 v. 2.9 Three-dimensional saline infusion sonography compared to two-dimensional saline infusion sonography .rm5 to CD011126 v. 2.9 Three-dimensional saline infusion sonography compared to two-dimensional saline infusion sonography .rm5
# Saving CD011134 v. 2.0 Blood CEA levels for detecting recurrent colorectal cancer.rm5 to CD011134 v. 2.0 Blood CEA levels for detecting recurrent colorectal cancer.rm5
# Saving CD011145 v. 3.0 Mini-Mental State Examination (MMSE) for the detection of dementia in clinically unevaluated people .rm5 to CD011145 v. 3.0 Mini-Mental State Examination (MMSE) for the detection of dementia in clinically unevaluated people .rm5
# Saving CD011221 v. 2.0 Tests for detecting strabismus in children aged 1 to 6 years in the community.rm5 to CD011221 v. 2.0 Tests for detecting strabismus in children aged 1 to 6 years in the community.rm5
# Saving CD011333 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the early diagnosis of deme.rm5 to CD011333 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the early diagnosis of deme.rm5
# Saving CD011414 v. 2.0 Mini-Cog for the diagnosis of Alzheimers disease dementia and other dementias within a secondary ca.rm5 to CD011414 v. 2.0 Mini-Cog for the diagnosis of Alzheimers disease dementia and other dementias within a secondary ca.rm5
# Saving CD011415 v. 2.0 Mini-Cog for the diagnosis of Alzheimers disease dementia and other dementias within a primary care.rm5 to CD011415 v. 2.0 Mini-Cog for the diagnosis of Alzheimers disease dementia and other dementias within a primary care.rm5
# Saving CD011420 v. 4.0 Lateral flow urine lipoarabinomannan assay for detecting active tuberculosis in people living with H.rm5 to CD011420 v. 4.0 Lateral flow urine lipoarabinomannan assay for detecting active tuberculosis in people living with H.rm5
# Saving CD011427 v. 2.0 Prehospital stroke scales as screening tools for early identification of stroke and transient ischem.rm5 to CD011427 v. 2.0 Prehospital stroke scales as screening tools for early identification of stroke and transient ischem.rm5
# Saving CD011431 v. 2.0 Rapid diagnostic tests for diagnosing uncomplicated non-falciparum or Plasmodium vivax malaria in en.rm5 to CD011431 v. 2.0 Rapid diagnostic tests for diagnosing uncomplicated non-falciparum or Plasmodium vivax malaria in en.rm5
# Saving CD011515 v. 2.0 Diagnostic accuracy of different imaging modalities following computed tomography (CT) scanning for .rm5 to CD011515 v. 2.0 Diagnostic accuracy of different imaging modalities following computed tomography (CT) scanning for .rm5
# Saving CD011548 v. 1.2 Ultrasound versus liver function tests for diagnosis of common bile duct stones.rm5 to CD011548 v. 1.2 Ultrasound versus liver function tests for diagnosis of common bile duct stones.rm5
# Saving CD011549 v. 1.2 Endoscopic ultrasound versus magnetic resonance cholangiopancreatography for common bile duct stones.rm5 to CD011549 v. 1.2 Endoscopic ultrasound versus magnetic resonance cholangiopancreatography for common bile duct stones.rm5
# Saving CD011551 v. 3.0 Magnetic resonance perfusion for differentiating low-grade from high-grade gliomas at first presenta.rm5 to CD011551 v. 3.0 Magnetic resonance perfusion for differentiating low-grade from high-grade gliomas at first presenta.rm5
# Saving CD011602 v. 2.2 Ultrasonography for diagnosis of alcoholic cirrhosis in people with alcoholic liver disease.rm5 to CD011602 v. 2.2 Ultrasonography for diagnosis of alcoholic cirrhosis in people with alcoholic liver disease.rm5
# Saving CD011686 v. 2.0 Triage tools for detecting cervical spine injury in pediatric trauma patients.rm5 to CD011686 v. 2.0 Triage tools for detecting cervical spine injury in pediatric trauma patients.rm5
# Saving CD011708 v. 2.0 Rapid point of care test for detecting urogenital Chlamydia trachomatis infection in nonpregnant wom.rm5 to CD011708 v. 2.0 Rapid point of care test for detecting urogenital Chlamydia trachomatis infection in nonpregnant wom.rm5
# Saving CD011767 v. 3.6 Genomics-based non-invasive prenatal testing for detection of fetal chromosomal aneuploidy in pregna.rm5 to CD011767 v. 3.6 Genomics-based non-invasive prenatal testing for detection of fetal chromosomal aneuploidy in pregna.rm5
# Saving CD011811 v. 3.0 Plasma interleukin-6 concentration for the diagnosis of sepsis in critically ill adults.rm5 to CD011811 v. 3.0 Plasma interleukin-6 concentration for the diagnosis of sepsis in critically ill adults.rm5
# Saving CD011871 v. 2.2 Nucleic acid and antigen detection tests for leptospirosis.rm5 to CD011871 v. 2.2 Nucleic acid and antigen detection tests for leptospirosis.rm5
# Saving CD011901 v. 3.0 Visual inspection and dermoscopy alone or in combination for diagnosing keratinocyte skin cancers .rm5 to CD011901 v. 3.0 Visual inspection and dermoscopy alone or in combination for diagnosing keratinocyte skin cancers .rm5
# Saving CD011902 v. 3.0 Dermoscopy with and without visual inspection for diagnosing melanoma in adults.rm5 to CD011902 v. 3.0 Dermoscopy with and without visual inspection for diagnosing melanoma in adults.rm5
# Saving CD011912 v. 2.0 Pulse oximetry screening for critical congenital heart defects.rm5 to CD011912 v. 2.0 Pulse oximetry screening for critical congenital heart defects.rm5
# Saving CD011926 v. 2.0 Molecular assays for the diagnosis of sepsis in neonates.rm5 to CD011926 v. 2.0 Molecular assays for the diagnosis of sepsis in neonates.rm5
# Saving CD011975 v. 1.0 First trimester serum tests for Down's syndrome screening.rm5 to CD011975 v. 1.0 First trimester serum tests for Down's syndrome screening.rm5
# Saving CD011984 v. 1.0 Urine tests for Down's syndrome screening.rm5 to CD011984 v. 1.0 Urine tests for Down's syndrome screening.rm5
# Saving CD012009 v. 2.0 Amylase in drain fluid for the diagnosis of pancreatic leak in post-pancreatic resection.rm5 to CD012009 v. 2.0 Amylase in drain fluid for the diagnosis of pancreatic leak in post-pancreatic resection.rm5
# Saving CD012010 v. 3.0 Serum amylase and lipase and urinary trypsinogen and amylase for diagnosis of acute pancreatitis.rm5 to CD012010 v. 3.0 Serum amylase and lipase and urinary trypsinogen and amylase for diagnosis of acute pancreatitis.rm5
# Saving CD012019 v. 1.3 Urinary biomarkers for the non-invasive diagnosis of endometriosis.rm5 to CD012019 v. 1.3 Urinary biomarkers for the non-invasive diagnosis of endometriosis.rm5
# Saving CD012080 v. 2.0 Non-invasive diagnostic tests for Helicobacter pylori infection.rm5 to CD012080 v. 2.0 Non-invasive diagnostic tests for Helicobacter pylori infection.rm5
# Saving CD012083 v. 2.0 Ultrasonography for confirmation of gastric tube placement.rm5 to CD012083 v. 2.0 Ultrasonography for confirmation of gastric tube placement.rm5
# Saving CD012126 v. 4.0 C-reactive protein for diagnosing late-onset infection in newborn infants.rm5 to CD012126 v. 4.0 C-reactive protein for diagnosing late-onset infection in newborn infants.rm5
# Saving CD012165 v. 1.0 Endometrial biomarkers for the non-invasive diagnosis of endometriosis.rm5 to CD012165 v. 1.0 Endometrial biomarkers for the non-invasive diagnosis of endometriosis.rm5
# Saving CD012179 v. 1.0 Blood biomarkers for the non-invasive diagnosis of endometriosis.rm5 to CD012179 v. 1.0 Blood biomarkers for the non-invasive diagnosis of endometriosis.rm5
# Saving CD012216 v. 2.0 18F PET with florbetapir for the early diagnosis of Alzheimers disease dementia and other dementias.rm5 to CD012216 v. 2.0 18F PET with florbetapir for the early diagnosis of Alzheimers disease dementia and other dementias.rm5
# Saving CD012233 v. 2.0 Transabdominal ultrasound and endoscopic ultrasound for diagnosis of gallbladder polyps.rm5 to CD012233 v. 2.0 Transabdominal ultrasound and endoscopic ultrasound for diagnosis of gallbladder polyps.rm5
# Saving CD012245 v. 3.0 Biochemical tests of placental function versus ultrasound assessment of fetal size for stillbirth an.rm5 to CD012245 v. 3.0 Biochemical tests of placental function versus ultrasound assessment of fetal size for stillbirth an.rm5
# Saving CD012267 v. 2.0 Biomarkers for diagnosis of Wilson's disease.rm5 to CD012267 v. 2.0 Biomarkers for diagnosis of Wilson's disease.rm5
# Saving CD012281 v. 1.6 Combination of the non-invasive tests for the diagnosis of endometriosis.rm5 to CD012281 v. 1.6 Combination of the non-invasive tests for the diagnosis of endometriosis.rm5
# Saving CD012399 v. 3.0 Galactomannan detection in broncho-alveolar lavage fluid for invasive aspergillosis in immunocomprom.rm5 to CD012399 v. 3.0 Galactomannan detection in broncho-alveolar lavage fluid for invasive aspergillosis in immunocomprom.rm5
# Saving CD012546 v. 2.0 Total serum bile acids or serum bile acid profile or both for the diagnosis of intrahepatic choles.rm5 to CD012546 v. 2.0 Total serum bile acids or serum bile acid profile or both for the diagnosis of intrahepatic choles.rm5
# Saving CD012567 v. 2.0 Positron emission tomography (PET) and magnetic resonance imaging (MRI) for assessing tumour resecta.rm5 to CD012567 v. 2.0 Positron emission tomography (PET) and magnetic resonance imaging (MRI) for assessing tumour resecta.rm5
# Saving CD012599 v. 1.2 First and second trimester serum tests with and without first trimester ultrasound tests for Down's .rm5 to CD012599 v. 1.2 First and second trimester serum tests with and without first trimester ultrasound tests for Down's .rm5
# Saving CD012600 v. 1.0 First trimester ultrasound tests alone or in combination with first trimester serum tests for Down's.rm5 to CD012600 v. 1.0 First trimester ultrasound tests alone or in combination with first trimester serum tests for Down's.rm5
# Saving CD012645 v. 1.0 Serum C-reactive protein procalcitonin and lactate dehydrogenase for the diagnosis of pancreatic n.rm5 to CD012645 v. 1.0 Serum C-reactive protein procalcitonin and lactate dehydrogenase for the diagnosis of pancreatic n.rm5
# Saving CD012663 v. 2.0 Prostate MRI with or without MRI-targeted biopsy and systematic biopsy for detecting prostate canc.rm5 to CD012663 v. 2.0 Prostate MRI with or without MRI-targeted biopsy and systematic biopsy for detecting prostate canc.rm5
# Saving CD012669 v. 2.12 Point-of-care ultrasonography for diagnosing thoracoabdominal injuries in patients with blunt trauma.rm5 to CD012669 v. 2.12 Point-of-care ultrasonography for diagnosing thoracoabdominal injuries in patients with blunt trauma.rm5
# Saving CD012768 v. 2.2 Xpert MTBRIF assay for extrapulmonary tuberculosis and rifampicin resistance.rm5 to CD012768 v. 2.2 Xpert MTBRIF assay for extrapulmonary tuberculosis and rifampicin resistance.rm5
# Saving CD012777 v. 2.0 Abdominal ultrasound for diagnosing abdominal tuberculosis or disseminated tuberculosis with abdomin.rm5 to CD012777 v. 2.0 Abdominal ultrasound for diagnosing abdominal tuberculosis or disseminated tuberculosis with abdomin.rm5
# Saving CD012806 v. 2.0 Ultrasound CT MRI or PET-CT for staging and re-staging of adults with cutaneous melanoma.rm5 to CD012806 v. 2.0 Ultrasound CT MRI or PET-CT for staging and re-staging of adults with cutaneous melanoma.rm5
# Saving CD012883 v. 1.0 18F PET with florbetaben for the early diagnosis of Alzheimer's disease dementia and other dementias.rm5 to CD012883 v. 1.0 18F PET with florbetaben for the early diagnosis of Alzheimer's disease dementia and other dementias.rm5
# Saving CD012884 v. 1.0 18F PET with flutemetamol for the early diagnosis of Alzheimer's disease dementia and other dementia.rm5 to CD012884 v. 1.0 18F PET with flutemetamol for the early diagnosis of Alzheimer's disease dementia and other dementia.rm5
# Saving CD013186 v. 2.0 Computer-assisted diagnosis techniques (dermoscopy and spectroscopy-based) for diagnosing skin cance.rm5 to CD013186 v. 2.0 Computer-assisted diagnosis techniques (dermoscopy and spectroscopy-based) for diagnosing skin cance.rm5
# Saving CD013187 v. 2.0 Exfoliative cytology for diagnosing basal cell carcinoma and other skin cancers in adults.rm5 to CD013187 v. 2.0 Exfoliative cytology for diagnosing basal cell carcinoma and other skin cancers in adults.rm5
# Saving CD013188 v. 2.0 High-frequency ultrasound for diagnosing skin cancer in adults.rm5 to CD013188 v. 2.0 High-frequency ultrasound for diagnosing skin cancer in adults.rm5
# Saving CD013189 v. 3.0 Optical coherence tomography for diagnosing skin cancer in adults.rm5 to CD013189 v. 3.0 Optical coherence tomography for diagnosing skin cancer in adults.rm5
# Saving CD013190 v. 2.0 Reflectance confocal microscopy for diagnosing cutaneous melanoma in adults.rm5 to CD013190 v. 2.0 Reflectance confocal microscopy for diagnosing cutaneous melanoma in adults.rm5
# Saving CD013191 v. 2.0 Reflectance confocal microscopy for diagnosing keratinocyte skin cancers in adults.rm5 to CD013191 v. 2.0 Reflectance confocal microscopy for diagnosing keratinocyte skin cancers in adults.rm5
# Saving CD013192 v. 2.0 Smartphone applications for triaging adults with skin lesions that are suspicious for melanoma.rm5 to CD013192 v. 2.0 Smartphone applications for triaging adults with skin lesions that are suspicious for melanoma.rm5
# Saving CD013193 v. 2.0 Teledermatology for diagnosing skin cancer in adults.rm5 to CD013193 v. 2.0 Teledermatology for diagnosing skin cancer in adults.rm5
# Saving CD013194 v. 2.0 Visual inspection for diagnosing cutaneous melanoma in adults.rm5 to CD013194 v. 2.0 Visual inspection for diagnosing cutaneous melanoma in adults.rm5
# Saving CD013282 v. 2.0 Addenbrookes Cognitive Examination III (ACE-III) and mini-ACE for the detection of dementia and mil.rm5 to CD013282 v. 2.0 Addenbrookes Cognitive Examination III (ACE-III) and mini-ACE for the detection of dementia and mil.rm5
# dict_keys(['CD007394 v. 4.0 Galactomannan detection for invasive aspergillosis in immunocompromised patients.rm5', 'CD007427 v. 3.0 Physical tests for shoulder impingements and local lesions of bursa tendon or labrum that may accom.rm5', 'CD007431 v. 4.0 Physical examination for lumbar radiculopathy due to disc herniation in patients with low-back pain.rm5', 'CD008054 v. 7.0 Human papillomavirus testing versus repeat cytology for triage of minor cytological cervical lesions.rm5', 'CD008081 v. 4.0 Optical coherence tomography (OCT) for detection of macular oedema in patients with diabetic retinop.rm5', 'CD008122 v. 4.0 Rapid diagnostic tests for diagnosing uncomplicated P. falciparum malaria in endemic countries.rm5', 'CD008587 v. 3.0 Cytology versus HPV testing for cervical cancer screening in the general population.rm5', 'CD008643 v. 4.3 Red flags to screen for vertebral fracture in patients presenting with low-back pain.rm5', 'CD008686 v. 3.2 Red flags to screen for malignancy in patients with low-back pain.rm5', 'CD008691 v. 2.0 Cardiac testing for coronary artery disease in potential kidney transplant recipients.rm5', 'CD008759 v. 3.0 Platelet count spleen length and platelet count-to-spleen length ratio for the diagnosis of oesoph.rm5', 'CD008760 v. 3.0 Capsule endoscopy for the diagnosis of oesophageal varices in people with chronic liver disease or p.rm5', "CD008782 v. 4.0 Plasma and cerebrospinal fluid amyloid beta for the diagnosis of Alzheimer's disease dementia and ot.rm5", 'CD008803 v. 2.0 Optic nerve head and fibre layer imaging for diagnosing glaucoma.rm5', 'CD008874 v. 6.0 Airway physical examination tests for detection of difficult airway management in apparently normal .rm5', 'CD008892 v. 2.0 Rapid diagnostic tests for typhoid and paratyphoid (enteric) fever.rm5', 'CD009020 v. 3.0 Magnetic resonance imaging magnetic resonance arthrography and ultrasonography for assessing rotato.rm5', 'CD009044 v. 2.0 Diagnostic tests for autism spectrum disorder (ASD) in preschool children.rm5', 'CD009135 v. 2.1 Rapid tests for the diagnosis of visceral leishmaniasis in patients with suspected disease.rm5', 'CD009175 v. 2.0 Clinical symptoms and signs for the diagnosis of Mycoplasma pneumoniae in children and adolescents w.rm5', 'CD009185 v. 2.163 Procalcitonin C-reactive protein and erythrocyte sedimentation rate for the diagnosis of acute pye.rm5', 'CD009263 v. 5.0 123I-MIBG scintigraphy and 18F-FDG-PET imaging for diagnosing neuroblastoma.rm5', 'CD009323 v. 4.0 Diagnostic accuracy of laparoscopy following computed tomography (CT) scanning for assessing the res.rm5', 'CD009372 v. 2.0 Computed tomography angiography or magnetic resonance angiography for detection of intracranial vasc.rm5', 'CD009519 v. 4.0 PET-CT for assessing mediastinal lymph node involvement in patients with suspected resectable non-sm.rm5', 'CD009551 v. 5.2 Polymerase chain reaction blood tests for the diagnosis of invasive aspergillosis in immunocompromis.rm5', 'CD009579 v. 3.0 Circulating antigen tests and urine reagent strips for diagnosis of active schistosomiasis in endemi.rm5', 'CD009591 v. 2.0 Imaging modalities for the non-invasive diagnosis of endometriosis.rm5', 'CD009593 v. 8.4 Xpert MTBRIF and Xpert MTBRIF Ultra for pulmonary tuberculosis and rifampicin resistance in adults.rm5', "CD009628 v. 2.0 Structural magnetic resonance imaging for the early diagnosis of dementia due to Alzheimer's disease.rm5", 'CD009647 v. 3.0 Clinical symptoms signs and tests for identification of impending and current water-loss dehydratio.rm5', 'CD009694 v. 4.0 Computed tomography (CT) angiography for confirmation of the clinical diagnosis of brain death.rm5', 'CD009786 v. 9.0 Laparoscopy for diagnosing resectability of disease in women with advanced ovarian cancer.rm5', "CD009925 v. 1.0 Second trimester serum tests for Down's Syndrome screening.rm5", 'CD009944 v. 2.0 Diagnostic accuracy of endoscopic ultrasonography (EUS) for the preoperative locoregional staging  ...
#
# Extracting data from: CD007394 v. 4.0 Galactomannan detection for invasive aspergillosis in immunocompromised patients.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=918 items; Study result data n=57 results
#
# Extracting data from: CD007427 v. 3.0 Physical tests for shoulder impingements and local lesions of bursa tendon or labrum that may accom.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=462 items; Study result data n=233 results
#
# Extracting data from: CD007431 v. 4.0 Physical examination for lumbar radiculopathy due to disc herniation in patients with low-back pain.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=280 items; Study result data n=283 results
#
# Extracting data from: CD008054 v. 7.0 Human papillomavirus testing versus repeat cytology for triage of minor cytological cervical lesions.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=473 items; Study result data n=545 results
#
# Extracting data from: CD008081 v. 4.0 Optical coherence tomography (OCT) for detection of macular oedema in patients with diabetic retinop.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=180 items; Study result data n=557 results
#
# Extracting data from: CD008122 v. 4.0 Rapid diagnostic tests for diagnosing uncomplicated P. falciparum malaria in endemic countries.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=801 items; Study result data n=893 results
#
# Extracting data from: CD008587 v. 3.0 Cytology versus HPV testing for cervical cancer screening in the general population.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=440 items; Study result data n=1093 results
#
# Extracting data from: CD008643 v. 4.3 Red flags to screen for vertebral fracture in patients presenting with low-back pain.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=88 items; Study result data n=1152 results
#
# Extracting data from: CD008686 v. 3.2 Red flags to screen for malignancy in patients with low-back pain.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=88 items; Study result data n=1183 results
#
# Extracting data from: CD008691 v. 2.0 Cardiac testing for coronary artery disease in potential kidney transplant recipients.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=275 items; Study result data n=1218 results
#
# Extracting data from: CD008759 v. 3.0 Platelet count spleen length and platelet count-to-spleen length ratio for the diagnosis of oesoph.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1307 items; Study result data n=1417 results
#
# Extracting data from: CD008760 v. 3.0 Capsule endoscopy for the diagnosis of oesophageal varices in people with chronic liver disease or p.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=272 items; Study result data n=1470 results
#
# Extracting data from: CD008782 v. 4.0 Plasma and cerebrospinal fluid amyloid beta for the diagnosis of Alzheimer's disease dementia and ot.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=289 items; Study result data n=1495 results
#
# Extracting data from: CD008803 v. 2.0 Optic nerve head and fibre layer imaging for diagnosing glaucoma.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=2014 items; Study result data n=2515 results
#
# Extracting data from: CD008874 v. 6.0 Airway physical examination tests for detection of difficult airway management in apparently normal .rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=2660 items; Study result data n=2881 results
#
# Extracting data from: CD008892 v. 2.0 Rapid diagnostic tests for typhoid and paratyphoid (enteric) fever.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=629 items; Study result data n=3035 results
#
# Extracting data from: CD009020 v. 3.0 Magnetic resonance imaging magnetic resonance arthrography and ultrasonography for assessing rotato.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=280 items; Study result data n=3096 results
#
# Extracting data from: CD009044 v. 2.0 Diagnostic tests for autism spectrum disorder (ASD) in preschool children.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=315 items; Study result data n=3117 results
#
# Extracting data from: CD009135 v. 2.1 Rapid tests for the diagnosis of visceral leishmaniasis in patients with suspected disease.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=510 items; Study result data n=3172 results
#
# Extracting data from: CD009175 v. 2.0 Clinical symptoms and signs for the diagnosis of Mycoplasma pneumoniae in children and adolescents w.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=77 items; Study result data n=3208 results
#
# Extracting data from: CD009185 v. 2.163 Procalcitonin C-reactive protein and erythrocyte sedimentation rate for the diagnosis of acute pye.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=264 items; Study result data n=3258 results
#
# Extracting data from: CD009263 v. 5.0 123I-MIBG scintigraphy and 18F-FDG-PET imaging for diagnosing neuroblastoma.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=176 items; Study result data n=3258 results
#
# Extracting data from: CD009323 v. 4.0 Diagnostic accuracy of laparoscopy following computed tomography (CT) scanning for assessing the res.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=256 items; Study result data n=3281 results
#
# Extracting data from: CD009372 v. 2.0 Computed tomography angiography or magnetic resonance angiography for detection of intracranial vasc.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=132 items; Study result data n=3292 results
#
# Extracting data from: CD009519 v. 4.0 PET-CT for assessing mediastinal lymph node involvement in patients with suspected resectable non-sm.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=810 items; Study result data n=3337 results
#
# Extracting data from: CD009551 v. 5.2 Polymerase chain reaction blood tests for the diagnosis of invasive aspergillosis in immunocompromis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=493 items; Study result data n=3454 results
#
# Extracting data from: CD009579 v. 3.0 Circulating antigen tests and urine reagent strips for diagnosis of active schistosomiasis in endemi.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=2241 items; Study result data n=3634 results
#
# Extracting data from: CD009591 v. 2.0 Imaging modalities for the non-invasive diagnosis of endometriosis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=931 items; Study result data n=3778 results
#
# Extracting data from: CD009593 v. 8.4 Xpert MTBRIF and Xpert MTBRIF Ultra for pulmonary tuberculosis and rifampicin resistance in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1710 items; Study result data n=4116 results
#
# Extracting data from: CD009628 v. 2.0 Structural magnetic resonance imaging for the early diagnosis of dementia due to Alzheimer's disease.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=594 items; Study result data n=4192 results
#
# Extracting data from: CD009647 v. 3.0 Clinical symptoms signs and tests for identification of impending and current water-loss dehydratio.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=288 items; Study result data n=4514 results
#
# Extracting data from: CD009694 v. 4.0 Computed tomography (CT) angiography for confirmation of the clinical diagnosis of brain death.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=380 items; Study result data n=4514 results
#
# Extracting data from: CD009786 v. 9.0 Laparoscopy for diagnosing resectability of disease in women with advanced ovarian cancer.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=360 items; Study result data n=4527 results
#
# Extracting data from: CD009925 v. 1.0 Second trimester serum tests for Down's Syndrome screening.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=590 items; Study result data n=4742 results
#
# Extracting data from: CD009944 v. 2.0 Diagnostic accuracy of endoscopic ultrasonography (EUS) for the preoperative locoregional staging of.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1122 items; Study result data n=4902 results
#
# Extracting data from: CD009977 v. 2.0 Computed tomography for diagnosis of acute appendicitis in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1408 items; Study result data n=5121 results
#
# Extracting data from: CD010023 v. 2.2 Computed tomography versus magnetic resonance imaging versus bone scintigraphy for clinically suspec.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=132 items; Study result data n=5136 results
#
# Extracting data from: CD010079 v. 2.0 Informant Questionnaire on Cognitive Decline in the Elderly (IQCODE) for the diagnosis of dementia w.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=220 items; Study result data n=5189 results
#
# Extracting data from: CD010159 v. 2.0 Calcitonin testing for detection of medullary thyroid cancer in people with thyroid nodules.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=272 items; Study result data n=5377 results
#
# Extracting data from: CD010173 v. 2.4 Clinical assessment to screen for the detection of oral cavity cancer and potentially malignant diso.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=234 items; Study result data n=5389 results
#
# Extracting data from: CD010213 v. 2.0 Imaging modalities for characterising focal pancreatic lesions.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=994 items; Study result data n=5462 results
#
# Extracting data from: CD010276 v. 2.7 Diagnostic tests for oral cancer and potentially malignant disorders in patients presenting with cli.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=756 items; Study result data n=5506 results
#
# Extracting data from: CD010296 v. 2.0 Ultrasonography for endoleak detection after endoluminal abdominal aortic aneurysm repair.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=462 items; Study result data n=5645 results
#
# Extracting data from: CD010339 v. 2.3 Endoscopic retrograde cholangiopancreatography versus intraoperative cholangiography for diagnosis o.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=160 items; Study result data n=5655 results
#
# Extracting data from: CD010360 v. 5.0 Intraoperative frozen section analysis for the diagnosis of early stage ovarian cancer in suspicious.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=722 items; Study result data n=5769 results
#
# Extracting data from: CD010386 v. 2.0 11C-PIB-PET for the early diagnosis of Alzheimers disease dementia and other dementias in people wi.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=153 items; Study result data n=5782 results
#
# Extracting data from: CD010409 v. 5.0 Sentinel node assessment for diagnosis of groin lymph node involvement in vulval cancer.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=578 items; Study result data n=5907 results
#
# Extracting data from: CD010438 v. 4.0 Thromboelastography (TEG) and rotational thromboelastometry (ROTEM) for traumainduced coagulopathy .rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=54 items; Study result data n=5911 results
#
# ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=68 items; Study result data n=7395 results
#
# Extracting data from: CD011420 v. 4.0 Lateral flow urine lipoarabinomannan assay for detecting active tuberculosis in people living with H.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=255 items; Study result data n=7479 results
#
# Extracting data from: CD011427 v. 2.0 Prehospital stroke scales as screening tools for early identification of stroke and transient ischem.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=437 items; Study result data n=7514 results
#
# Extracting data from: CD011431 v. 2.0 Rapid diagnostic tests for diagnosing uncomplicated non-falciparum or Plasmodium vivax malaria in en.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=423 items; Study result data n=7640 results
#
# Extracting data from: CD011515 v. 2.0 Diagnostic accuracy of different imaging modalities following computed tomography (CT) scanning for .rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=32 items; Study result data n=7642 results
#
# Extracting data from: CD011548 v. 1.2 Ultrasound versus liver function tests for diagnosis of common bile duct stones.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=85 items; Study result data n=7651 results
#
# Extracting data from: CD011549 v. 1.2 Endoscopic ultrasound versus magnetic resonance cholangiopancreatography for common bile duct stones.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=276 items; Study result data n=7671 results
#
# Extracting data from: CD011551 v. 3.0 Magnetic resonance perfusion for differentiating low-grade from high-grade gliomas at first presenta.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=133 items; Study result data n=7678 results
#
# Extracting data from: CD011602 v. 2.2 Ultrasonography for diagnosis of alcoholic cirrhosis in people with alcoholic liver disease.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=34 items; Study result data n=7694 results
#
# Extracting data from: CD011686 v. 2.0 Triage tools for detecting cervical spine injury in pediatric trauma patients.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=51 items; Study result data n=7698 results
#
# Extracting data from: CD011708 v. 2.0 Rapid point of care test for detecting urogenital Chlamydia trachomatis infection in nonpregnant wom.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=475 items; Study result data n=7798 results
#
# Extracting data from: CD011767 v. 3.6 Genomics-based non-invasive prenatal testing for detection of fetal chromosomal aneuploidy in pregna.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1125 items; Study result data n=8149 results
#
# Extracting data from: CD011811 v. 3.0 Plasma interleukin-6 concentration for the diagnosis of sepsis in critically ill adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=414 items; Study result data n=8170 results
#
# Extracting data from: CD011871 v. 2.2 Nucleic acid and antigen detection tests for leptospirosis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=979 items; Study result data n=8245 results
#
# Extracting data from: CD011901 v. 3.0 Visual inspection and dermoscopy alone or in combination for diagnosing keratinocyte skin cancers .rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=744 items; Study result data n=8417 results
#
# Extracting data from: CD011902 v. 3.0 Dermoscopy with and without visual inspection for diagnosing melanoma in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=3263 items; Study result data n=9014 results
#
# Extracting data from: CD011912 v. 2.0 Pulse oximetry screening for critical congenital heart defects.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=336 items; Study result data n=9054 results
#
# Extracting data from: CD011926 v. 2.0 Molecular assays for the diagnosis of sepsis in neonates.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=595 items; Study result data n=9143 results
#
# Extracting data from: CD011975 v. 1.0 First trimester serum tests for Down's syndrome screening.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=560 items; Study result data n=9422 results
#
# Extracting data from: CD011984 v. 1.0 Urine tests for Down's syndrome screening.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=190 items; Study result data n=9498 results
#
# Extracting data from: CD012009 v. 2.0 Amylase in drain fluid for the diagnosis of pancreatic leak in post-pancreatic resection.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=90 items; Study result data n=9503 results
#
# Extracting data from: CD012010 v. 3.0 Serum amylase and lipase and urinary trypsinogen and amylase for diagnosis of acute pancreatitis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=238 items; Study result data n=9557 results
#
# Extracting data from: CD012019 v. 1.3 Urinary biomarkers for the non-invasive diagnosis of endometriosis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=144 items; Study result data n=9567 results
#
# Extracting data from: CD012080 v. 2.0 Non-invasive diagnostic tests for Helicobacter pylori infection.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1793 items; Study result data n=9730 results
#
# Extracting data from: CD012083 v. 2.0 Ultrasonography for confirmation of gastric tube placement.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=200 items; Study result data n=9740 results
#
# Extracting data from: CD012126 v. 4.0 C-reactive protein for diagnosing late-onset infection in newborn infants.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=340 items; Study result data n=9760 results
#
# Extracting data from: CD012165 v. 1.0 Endometrial biomarkers for the non-invasive diagnosis of endometriosis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=972 items; Study result data n=9808 results
#
# Extracting data from: CD012179 v. 1.0 Blood biomarkers for the non-invasive diagnosis of endometriosis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=2538 items; Study result data n=10015 results
#
# Extracting data from: CD012216 v. 2.0 18F PET with florbetapir for the early diagnosis of Alzheimers disease dementia and other dementias.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=60 items; Study result data n=10019 results
#
# Extracting data from: CD012233 v. 2.0 Transabdominal ultrasound and endoscopic ultrasound for diagnosis of gallbladder polyps.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=292 items; Study result data n=10041 results
#
# Extracting data from: CD012245 v. 3.0 Biochemical tests of placental function versus ultrasound assessment of fetal size for stillbirth an.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1607 items; Study result data n=10238 results
#
# Extracting data from: CD012267 v. 2.0 Biomarkers for diagnosis of Wilson's disease.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=144 items; Study result data n=10262 results
#
# Extracting data from: CD012281 v. 1.6 Combination of the non-invasive tests for the diagnosis of endometriosis.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=231 items; Study result data n=10289 results
#
# Extracting data from: CD012399 v. 3.0 Galactomannan detection in broncho-alveolar lavage fluid for invasive aspergillosis in immunocomprom.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=340 items; Study result data n=10329 results
#
# Extracting data from: CD012546 v. 2.0 Total serum bile acids or serum bile acid profile or both for the diagnosis of intrahepatic choles.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=296 items; Study result data n=10407 results
#
# Extracting data from: CD012567 v. 2.0 Positron emission tomography (PET) and magnetic resonance imaging (MRI) for assessing tumour resecta.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=125 items; Study result data n=10412 results
#
# Extracting data from: CD012599 v. 1.2 First and second trimester serum tests with and without first trimester ultrasound tests for Down's .rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=220 items; Study result data n=10529 results
#
# Extracting data from: CD012600 v. 1.0 First trimester ultrasound tests alone or in combination with first trimester serum tests for Down's.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1260 items; Study result data n=11023 results
#
# Extracting data from: CD012645 v. 1.0 Serum C-reactive protein procalcitonin and lactate dehydrogenase for the diagnosis of pancreatic n.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=51 items; Study result data n=11028 results
#
# Extracting data from: CD012663 v. 2.0 Prostate MRI with or without MRI-targeted biopsy and systematic biopsy for detecting prostate canc.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=898 items; Study result data n=11727 results
#
# Extracting data from: CD012669 v. 2.12 Point-of-care ultrasonography for diagnosing thoracoabdominal injuries in patients with blunt trauma.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=816 items; Study result data n=11795 results
#
# Extracting data from: CD012768 v. 2.2 Xpert MTBRIF assay for extrapulmonary tuberculosis and rifampicin resistance.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1188 items; Study result data n=12017 results
#
# Extracting data from: CD012777 v. 2.0 Abdominal ultrasound for diagnosing abdominal tuberculosis or disseminated tuberculosis with abdomin.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=374 items; Study result data n=12058 results
#
# Extracting data from: CD012806 v. 2.0 Ultrasound CT MRI or PET-CT for staging and re-staging of adults with cutaneous melanoma.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1118 items; Study result data n=12243 results
#
# Extracting data from: CD012883 v. 1.0 18F PET with florbetaben for the early diagnosis of Alzheimer's disease dementia and other dementias.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=20 items; Study result data n=12249 results
#
# Extracting data from: CD012884 v. 1.0 18F PET with flutemetamol for the early diagnosis of Alzheimer's disease dementia and other dementia.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=40 items; Study result data n=12251 results
#
# Extracting data from: CD013186 v. 2.0 Computer-assisted diagnosis techniques (dermoscopy and spectroscopy-based) for diagnosing skin cance.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1446 items; Study result data n=12429 results
#
# Extracting data from: CD013187 v. 2.0 Exfoliative cytology for diagnosing basal cell carcinoma and other skin cancers in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=232 items; Study result data n=12464 results
#
# Extracting data from: CD013188 v. 2.0 High-frequency ultrasound for diagnosing skin cancer in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=150 items; Study result data n=12490 results
#
# Extracting data from: CD013189 v. 3.0 Optical coherence tomography for diagnosing skin cancer in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=182 items; Study result data n=12503 results
#
# Extracting data from: CD013190 v. 2.0 Reflectance confocal microscopy for diagnosing cutaneous melanoma in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=651 items; Study result data n=12634 results
#
# Extracting data from: CD013191 v. 2.0 Reflectance confocal microscopy for diagnosing keratinocyte skin cancers in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=308 items; Study result data n=12713 results
#
# Extracting data from: CD013192 v. 2.0 Smartphone applications for triaging adults with skin lesions that are suspicious for melanoma.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=50 items; Study result data n=12720 results
#
# Extracting data from: CD013193 v. 2.0 Teledermatology for diagnosing skin cancer in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=622 items; Study result data n=12766 results
#
# Extracting data from: CD013194 v. 2.0 Visual inspection for diagnosing cutaneous melanoma in adults.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=1393 items; Study result data n=12987 results
#
# Extracting data from: CD013282 v. 2.0 Addenbrookes Cognitive Examination III (ACE-III) and mini-ACE for the detection of dementia and mil.rm5 ...
#    Extracting basic review info, bias data, stats data...
#    Extracted: review metadata n=1; Study bias data n=140 items; Study result data n=13001 results
